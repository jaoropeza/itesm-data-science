# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
total = np.loadtxt('datos2.txt')
total = np.transpose(total)
x1s = total[0]
x2s = total[1]
ys = total[2]
w = np.zeros((3,3))

# %%
color = np.where(ys == 0, 'r', np.where(ys == 1, 'g', 'y'))
plt.scatter(x1s, x2s, c=color, marker='x', s=20)
plt.show()
